# %% [markdown]
# <a href="https://colab.research.google.com/github/nicholasketo/Stock-Market-Value-Prediction/blob/main/Quant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install xlsxwriter
# Out:
# Requirement already satisfied: xlsxwriter in /usr/local/lib/python3.10/dist-packages (3.1.9)

# %%
import numpy as np
import pandas as pd
import requests as rq #internet request to get HTTP request
import xlsxwriter #save well formatted excel from python
import math
import csv

# %%
url = 'https://raw.githubusercontent.com/nicholasketo/Stock-Market-Value-Prediction/main/sp_500_stocks.csv'
stocks = pd.read_csv(url)
stocks
# Out:
#     Ticker
# 0        A
# 1      AAL
# 2      AAP
# 3     AAPL
# 4     ABBV
# ..     ...
# 500    YUM
# 501    ZBH
# 502   ZBRA
# 503   ZION
# 504    ZTS
#
# [505 rows x 1 columns]

# %%
from secrets import IEX_CLOUD_API_TOKEN
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-abfd580c5793> in <cell line: 1>()
# ----> 1 from secrets import IEX_CLOUD_API_TOKEN
#
# ImportError: cannot import name 'IEX_CLOUD_API_TOKEN' from 'secrets' (/usr/lib/python3.10/secrets.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
